# %%
import geopandas as gpd
from shapely.geometry import LineString, MultiLineString, MultiPolygon, Polygon
from shapely.ops import unary_union, split, linemerge, polygonize
import shapely as shp
import pandas as pd
import networkx as nx

# %%
# Carregar o arquivo grid.parquet
grid_gdf = gpd.read_file("test/grid.shp")
unidade_split = grid_gdf[grid_gdf["id"] == 1].geometry.values[0]  # Pega a geometria do grid_id 22
# Verifique se o polígono foi carregado corretamente
unidade_split
# Out:
# <POLYGON ((-46.269 -9.205, -46.259 -9.177, -46.168 -9.179, -46.172 -9.255, -...>

# %%
gdf_input = gpd.read_file("test/test_feature.shp")
gdf_input
# Out:
#    id                                           geometry
# 0   1  POLYGON ((-46.24614 -9.20888, -46.23956 -9.213...
# 1   2  POLYGON ((-46.23436 -9.22484, -46.23411 -9.215...
# 2   3  POLYGON ((-46.2431 -9.21775, -46.23158 -9.2224...

# %%
 # Verificar interseção e selecionar geometrias que tocam unidade_split
gdf_intersects = gdf_input[gdf_input.intersects(unidade_split)].reset_index(drop=True)
gdf_intersects
# Out:
#    id                                           geometry
# 0   1  POLYGON ((-46.24614 -9.20888, -46.23956 -9.213...
# 1   2  POLYGON ((-46.23436 -9.22484, -46.23411 -9.215...
# 2   3  POLYGON ((-46.2431 -9.21775, -46.23158 -9.2224...

# %%
# Lista de LineStrings representando os limites
lines = [geom for geom in gdf_intersects.geometry.boundary]
lines.append(unidade_split.boundary)

# Intersecciona cada LineString com o contorno de unidade_split para eliminar as partes fora
clipped_lines = [line.intersection(unidade_split) for line in lines if not line.is_empty]


# Cria o MultiLineString a partir das linhas
multi_line = MultiLineString(lines)

# Usa shapely.node para adicionar nós (pontos de interseção) ao MultiLineString
multi_line_with_nodes = shp.node(multi_line)

# Usa polygonize para gerar polígonos fechados a partir do MultiLineString com nós
polygons = list(polygonize(multi_line_with_nodes))
polygons
# Out:
# [<POLYGON ((-46.246 -9.209, -46.24 -9.214, -46.241 -9.218, -46.243 -9.218, -4...>,
#  <POLYGON ((-46.241 -9.218, -46.243 -9.223, -46.244 -9.223, -46.243 -9.218, -...>,
#  <POLYGON ((-46.244 -9.223, -46.243 -9.223, -46.241 -9.218, -46.234 -9.221, -...>,
#  <POLYGON ((-46.234 -9.225, -46.234 -9.221, -46.232 -9.222, -46.234 -9.227, -...>,
#  <POLYGON ((-46.234 -9.221, -46.234 -9.216, -46.231 -9.215, -46.225 -9.217, -...>,
#  <POLYGON ((-46.269 -9.205, -46.259 -9.177, -46.168 -9.179, -46.172 -9.255, -...>]

# %%
#lines = [linemerge(geom.boundary) for geom in gdf_intersects.geometry]
combined_points = []

for linestring in lines:
    print(list(linestring.coords))    
    combined_points.extend(list(linestring.coords))

combined_points
forced_line = LineString(combined_points)
forced_line
# Out:
# [(-46.24614099422522, -9.208884011014431), (-46.23955566598696, -9.213696366265465), (-46.24297497103375, -9.223194435839876), (-46.25070006762094, -9.222561231201581), (-46.25323288617412, -9.213949648120783), (-46.25259968153582, -9.210150420291018), (-46.24614099422522, -9.208884011014431)]
# [(-46.23436338795295, -9.22484076789944), (-46.23411010609764, -9.215722621108005), (-46.23081744197851, -9.215089416469713), (-46.22537188208918, -9.216609107601618), (-46.22359890910196, -9.223194435839876), (-46.22486531837855, -9.227753509235592), (-46.22841126435299, -9.232565864486627), (-46.23436338795295, -9.231552737065357), (-46.23436338795295, -9.22484076789944)]
# [(-46.243101611961414, -9.217748875950546), (-46.23157728754446, -9.222434590273922), (-46.23803597485506, -9.232439223558968), (-46.24626763515288, -9.230286327788768), (-46.243101611961414, -9.217748875950546)]
# <LINESTRING (-46.246 -9.209, -46.24 -9.214, -46.243 -9.223, -46.251 -9.223, ...>

# %%
ry) for geom in gdf_intersects.geometry]
combined_points = []

for linestring in lines:
    print(list(linestring.coords))

# %%
combined_points.extend(list(linestring.coords))

combined_points
forced_line = LineString(combined_points)
forced_line

# %%
combined_points = []

for line in lines_gdf.geometry:
    # Verifica se a geometria é LineString ou MultiLineString
    if isinstance(line, LineString):
        # Se for LineString, adiciona as coordenadas diretamente
        combined_points.extend(list(line.coords))
    elif isinstance(line, MultiLineString):
        # Se for MultiLineString, extrai as coordenadas de cada LineString componente
        for linestring in line.geoms:
            combined_points.extend(list(linestring.coords))
    else:
        # Lança um erro para tipos de geometria não suportados
        raise TypeError(f"Tipo de geometria não suportado: {type(line)}")

# Cria uma única LineString a partir dos pontos combinados
forced_line = LineString(combined_points)

# %%
    elif isinstance(line, MultiLineString):
        # Se for MultiLineString, extrai as coordenadas de cada LineString componente
        for linestring in line.geoms:
            combined_points.extend(list(linestring.coords))
    else:
        # Lança um erro para tipos de geometria não suportados
        raise TypeError(f"Tipo de geometria não suportado: {type(line)}")

# Cria uma única LineString a partir dos pontos combinados
forced_line = LineString(combined_points)

# %%
forced_line
# Out:
# <LINESTRING (-40.174 -2.825, -40.174 -2.825, -40.174 -2.825, -40.174 -2.825,...>

# %%
broken_glass = split(unidade_split, forced_line)

# %%
broken_glass_polygon = MultiPolygon(broken_glass)
broken_glass_polygon.geom_type
geometries = list(broken_glass_polygon.geoms)

# %%
gdf_broken_glass = gpd.GeoDataFrame(data = {"id":range(1,len(broken_glass_polygon.geoms)+1)}, geometry=geometries, crs = 4674 )
gdf_broken_glass.geometry[0]
# Out:
# <POLYGON ((-40.1 -3.1, -40.1 -3.1, -40.099 -3.099, -40.099 -3.1, -40.1 -3.1))>

# %%
gdf_broken_glass["representative_point"] = gdf_broken_glass.geometry.apply(lambda x: x.representative_point())
gdf_broken_glass
# Out:
#           id                                           geometry  \
# 0          1  POLYGON ((-40.1 -3.1, -40.1 -3.0995, -40.09858...
# 1          2  POLYGON ((-40.1 -3.0995, -40.1 -3.09637, -40.0...
# 2          3  POLYGON ((-40.1 -3.09637, -40.1 -3.09065, -40....
# 3          4  POLYGON ((-40.1 -3.06524, -40.1 -3.06281, -40....
# 4          5  POLYGON ((-40.1 -3.06281, -40.1 -3.0395, -40.0...
# ...      ...                                                ...
# 16340  16341  POLYGON ((-40.03034 -3.05797, -40.03034 -3.057...
# 16341  16342  POLYGON ((-40.03037 -3.05786, -40.03034 -3.057...
# 16342  16343  POLYGON ((-40.02846 -3.05844, -40.02846 -3.058...
# 16343  16344  POLYGON ((-40.02894 -3.05833, -40.02846 -3.058...
# 16344  16345  POLYGON ((-40.02891 -3.01354, -40.02896 -3.013...
#
#              representative_point
# 0      POINT (-40.09929 -3.09975)
# 1      POINT (-40.09253 -3.08172)
# 2      POINT (-40.09973 -3.09325)
# 3      POINT (-40.08411 -3.08158)
# 4      POINT (-40.08659 -3.07083)
# ...                           ...
# 16340  POINT (-40.03036 -3.05798)
# 16341  POINT (-40.03038 -3.05791)
# 16342  POINT (-40.02846 -3.05844)
# 16343  POINT (-40.02889 -3.05852)
# 16344  POINT (-40.02901 -3.01361)
#
# [16345 rows x 3 columns]

# %%
# Criar lista para armazenar informações de correlação de glass_shard com input_split
correlation_data = []


for index, shard in gdf_broken_glass.iterrows():
    glass_shard_point = shard["representative_point"]
    
    # Selecionar polígonos de input_split que sobrepõem o ponto representativo
    overlapping_polygons = gdf_input[gdf_input.contains(glass_shard_point)]
    
    # Verificar se há sobreposição
    if not overlapping_polygons.empty:
        # Extrair id_layer e id dos polígonos que sobrepõem o ponto representativo
        ids = overlapping_polygons["id"].tolist()
        id_layers = overlapping_polygons["id_layer"].tolist()
    else:
        # Caso não haja sobreposição, atribuir "void" e o id do unidade_split
        ids = [n_grid]
        id_layers = ["void"]
    
    # Adicionar ao dicionário de correlação
    correlation_data.append({
        "id": ids,
        "id_layer": id_layers
    })




correlation_data
# Out:
# [{'id': [22], 'id_layer': ['void']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310, 418507], 'id_layer': ['CAR', 'CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310, 463299], 'id_layer': ['CAR', 'CAR']},
#  {'id': [984310, 463299], 'id_layer': ['CAR', 'CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [805190], 'id_layer': ['CAR']},
#  {'id': [805190], 'id_layer': ['CAR']},
#  {'id': [805190], 'id_layer': ['CAR']},
#  {'id': [805190], 'id_layer': ['CAR']},
#  {'id': [805190], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [907963], 'id_layer': ['CAR']},
#  {'id': [907963], 'id_layer': ['CAR']},
#  {'id': [907963], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [861066], 'id_layer': ['CAR']},
#  {'id': [861066, 921148], 'id_layer': ['CAR', 'CAR']},
#  {'id': [861066, 921148], 'id_layer': ['CAR', 'CAR']},
#  {'id': [861066, 921148], 'id_layer': ['CAR', 'CAR']},
#  {'id': [861066, 921148], 'id_layer': ['CAR', 'CAR']},
#  {'id': [861066, 921148], 'id_layer': ['CAR', 'CAR']},
#  {'id': [861066], 'id_layer': ['CAR']},
#  {'id': [861066, 918818], 'id_layer': ['CAR', 'CAR']},
#  {'id': [918818], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [922491], 'id_layer': ['CAR']},
#  {'id': [767646, 922491], 'id_layer': ['CAR', 'CAR']},
#  {'id': [767646], 'id_layer': ['CAR']},
#  {'id': [767646], 'id_layer': ['CAR']},
#  {'id': [767646], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [828818], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [720205], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [728839], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [828818], 'id_layer': ['CAR']},
#  {'id': [828818, 978101], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [749952, 978101], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [806275], 'id_layer': ['CAR']},
#  {'id': [806275], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [939923], 'id_layer': ['CAR']},
#  {'id': [939923], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [943999], 'id_layer': ['CAR']},
#  {'id': [772075, 943999], 'id_layer': ['CAR', 'CAR']},
#  {'id': [943999], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [761004], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [761004], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [794171], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [764221], 'id_layer': ['CAR']},
#  {'id': [764221], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [772074], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [773104], 'id_layer': ['CAR']},
#  {'id': [773104, 896562], 'id_layer': ['CAR', 'CAR']},
#  {'id': [764224, 773104], 'id_layer': ['CAR', 'CAR']},
#  {'id': [764224], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [975441, 984310], 'id_layer': ['CAR', 'CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310, 714599], 'id_layer': ['CAR', 'CAR']},
#  {'id': [984310, 714599], 'id_layer': ['CAR', 'CAR']},
#  {'id': [984310, 714599], 'id_layer': ['CAR', 'CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310, 979841], 'id_layer': ['CAR', 'CAR']},
#  {'id': [654973], 'id_layer': ['CAR']},
#  {'id': [746350, 654973], 'id_layer': ['CAR', 'CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [746350], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [746350, 978101], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [746350, 978101], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978101, 654973], 'id_layer': ['CAR', 'CAR']},
#  {'id': [746350, 978101, 654973], 'id_layer': ['CAR', 'CAR', 'CAR']},
#  {'id': [654973], 'id_layer': ['CAR']},
#  {'id': [746350, 654973], 'id_layer': ['CAR', 'CAR']},
#  {'id': [654973], 'id_layer': ['CAR']},
#  {'id': [746350, 654973], 'id_layer': ['CAR', 'CAR']},
#  {'id': [654973], 'id_layer': ['CAR']},
#  {'id': [746350, 654973], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978101, 654973], 'id_layer': ['CAR', 'CAR']},
#  {'id': [746350, 978101, 654973], 'id_layer': ['CAR', 'CAR', 'CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [746350, 978101], 'id_layer': ['CAR', 'CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [746350], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [746350], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [746350], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [746350], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [746350], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [746350], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [746350], 'id_layer': ['CAR']},
#  {'id': [654973], 'id_layer': ['CAR']},
#  {'id': [746350, 654973], 'id_layer': ['CAR', 'CAR']},
#  {'id': [654973], 'id_layer': ['CAR']},
#  {'id': [746350, 654973], 'id_layer': ['CAR', 'CAR']},
#  {'id': [654973], 'id_layer': ['CAR']},
#  {'id': [746350, 654973], 'id_layer': ['CAR', 'CAR']},
#  {'id': [654973], 'id_layer': ['CAR']},
#  {'id': [746350, 654973], 'id_layer': ['CAR', 'CAR']},
#  {'id': [654973], 'id_layer': ['CAR']},
#  {'id': [654973], 'id_layer': ['CAR']},
#  {'id': [654973], 'id_layer': ['CAR']},
#  {'id': [654973], 'id_layer': ['CAR']},
#  {'id': [746350, 654973], 'id_layer': ['CAR', 'CAR']},
#  {'id': [654973], 'id_layer': ['CAR']},
#  {'id': [746350, 654973], 'id_layer': ['CAR', 'CAR']},
#  {'id': [654973], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978101], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 978101], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [749952, 978101], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [749952, 978101], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [749952, 978101], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [749952, 978101], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [749952, 978101], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [749952, 978101], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [749952], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [749952], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [749952], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [749952], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952, 791398], 'id_layer': ['CAR', 'CAR']},
#  {'id': [791398], 'id_layer': ['CAR']},
#  {'id': [749952], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [749952, 984310, 978107], 'id_layer': ['CAR', 'CAR', 'CAR']},
#  {'id': [984310, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 984310, 978107], 'id_layer': ['CAR', 'CAR', 'CAR']},
#  {'id': [984310, 978107], 'id_layer': ['CAR', 'CAR']},
#  {'id': [749952, 984310], 'id_layer': ['CAR', 'CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [749952, 984310], 'id_layer': ['CAR', 'CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [749952, 984310], 'id_layer': ['CAR', 'CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [749952], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [749952], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [978107], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [984310], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [978101], 'id_layer': ['CAR']},
#  {'id': [946547, 978101], 'id_layer': ['CAR', 'CAR']},
#  {'id': [946547, 978101], 'id_layer': ['CAR', 'CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [946547], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [757939], 'id_layer': ['CAR']},
#  {'id': [757939], 'id_layer': ['CAR']},
#  {'id': [757939], 'id_layer': ['CAR']},
#  {'id': [757939], 'id_layer': ['CAR']},
#  {'id': [757939], 'id_layer': ['CAR']},
#  {'id': [757939], 'id_layer': ['CAR']},
#  {'id': [757939], 'id_layer': ['CAR']},
#  {'id': [757939], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [899289], 'id_layer': ['CAR']},
#  {'id': [899289], 'id_layer': ['CAR']},
#  {'id': [899289], 'id_layer': ['CAR']},
#  {'id': [899289], 'id_layer': ['CAR']},
#  {'id': [899289], 'id_layer': ['CAR']},
#  {'id': [899289], 'id_layer': ['CAR']},
#  {'id': [899289], 'id_layer': ['CAR']},
#  {'id': [899289], 'id_layer': ['CAR']},
#  {'id': [899289], 'id_layer': ['CAR']},
#  {'id': [899289], 'id_layer': ['CAR']},
#  {'id': [899289], 'id_layer': ['CAR']},
#  {'id': [899289], 'id_layer': ['CAR']},
#  {'id': [899289], 'id_layer': ['CAR']},
#  {'id': [899289], 'id_layer': ['CAR']},
#  {'id': [899289], 'id_layer': ['CAR']},
#  {'id': [899289], 'id_layer': ['CAR']},
#  {'id': [832846], 'id_layer': ['CAR']},
#  {'id': [832846], 'id_layer': ['CAR']},
#  {'id': [832846], 'id_layer': ['CAR']},
#  {'id': [832846], 'id_layer': ['CAR']},
#  {'id': [832846], 'id_layer': ['CAR']},
#  {'id': [832846], 'id_layer': ['CAR']},
#  {'id': [904695], 'id_layer': ['CAR']},
#  {'id': [904695], 'id_layer': ['CAR']},
#  {'id': [904695], 'id_layer': ['CAR']},
#  {'id': [904695], 'id_layer': ['CAR']},
#  {'id': [904695], 'id_layer': ['CAR']},
#  {'id': [904695], 'id_layer': ['CAR']},
#  {'id': [904695], 'id_layer': ['CAR']},
#  {'id': [904695], 'id_layer': ['CAR']},
#  {'id': [901232], 'id_layer': ['CAR']},
#  {'id': [901232], 'id_layer': ['CAR']},
#  {'id': [910690, 901232], 'id_layer': ['CAR', 'CAR']},
#  {'id': [910690, 901232], 'id_layer': ['CAR', 'CAR']},
#  {'id': [910690], 'id_layer': ['CAR']},
#  {'id': [910690], 'id_layer': ['CAR']},
#  {'id': [910690], 'id_layer': ['CAR']},
#  {'id': [910690], 'id_layer': ['CAR']},
#  {'id': [910690], 'id_layer': ['CAR']},
#  {'id': [910690], 'id_layer': ['CAR']},
#  {'id': [910690], 'id_layer': ['CAR']},
#  {'id': [910690], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [901263], 'id_layer': ['CAR']},
#  {'id': [901263], 'id_layer': ['CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [751983], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [751983], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [751983], 'id_layer': ['CAR']},
#  {'id': [929755], 'id_layer': ['CAR']},
#  {'id': [751983, 929755], 'id_layer': ['CAR', 'CAR']},
#  {'id': [929755], 'id_layer': ['CAR']},
#  {'id': [751983, 929755], 'id_layer': ['CAR', 'CAR']},
#  {'id': [892826], 'id_layer': ['CAR']},
#  {'id': [751983, 892826], 'id_layer': ['CAR', 'CAR']},
#  {'id': [910410], 'id_layer': ['CAR']},
#  {'id': [751983, 910410], 'id_layer': ['CAR', 'CAR']},
#  {'id': [910410], 'id_layer': ['CAR']},
#  {'id': [751983, 910410], 'id_layer': ['CAR', 'CAR']},
#  {'id': [922063], 'id_layer': ['CAR']},
#  {'id': [751983, 922063], 'id_layer': ['CAR', 'CAR']},
#  {'id': [922063], 'id_layer': ['CAR']},
#  {'id': [751983, 922063], 'id_layer': ['CAR', 'CAR']},
#  {'id': [922063], 'id_layer': ['CAR']},
#  {'id': [751983, 922063], 'id_layer': ['CAR', 'CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [751983], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [751983], 'id_layer': ['CAR']},
#  {'id': [910410], 'id_layer': ['CAR']},
#  {'id': [751983, 910410], 'id_layer': ['CAR', 'CAR']},
#  {'id': [751983], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [751983], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [751983], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [751983], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [751983], 'id_layer': ['CAR']},
#  {'id': [961680], 'id_layer': ['CAR']},
#  {'id': [751983, 961680], 'id_layer': ['CAR', 'CAR']},
#  {'id': [910410, 961680], 'id_layer': ['CAR', 'CAR']},
#  {'id': [751983, 910410, 961680], 'id_layer': ['CAR', 'CAR', 'CAR']},
#  {'id': [751983, 961680], 'id_layer': ['CAR', 'CAR']},
#  {'id': [961680], 'id_layer': ['CAR']},
#  {'id': [751983, 961680], 'id_layer': ['CAR', 'CAR']},
#  {'id': [961680], 'id_layer': ['CAR']},
#  {'id': [751983, 961680], 'id_layer': ['CAR', 'CAR']},
#  {'id': [961680], 'id_layer': ['CAR']},
#  {'id': [751983, 961680], 'id_layer': ['CAR', 'CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [751983], 'id_layer': ['CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [751983, 909057], 'id_layer': ['CAR', 'CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [751983, 909057], 'id_layer': ['CAR', 'CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [751983], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [751983], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [751983], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [751983], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [751983], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [751983], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [751983], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [909057], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [961680], 'id_layer': ['CAR']},
#  {'id': [961680], 'id_layer': ['CAR']},
#  {'id': [961680], 'id_layer': ['CAR']},
#  {'id': [961680], 'id_layer': ['CAR']},
#  {'id': [961680], 'id_layer': ['CAR']},
#  {'id': [961680], 'id_layer': ['CAR']},
#  {'id': [961680], 'id_layer': ['CAR']},
#  {'id': [961680], 'id_layer': ['CAR']},
#  {'id': [961680], 'id_layer': ['CAR']},
#  {'id': [961680], 'id_layer': ['CAR']},
#  {'id': [961680], 'id_layer': ['CAR']},
#  {'id': [961680], 'id_layer': ['CAR']},
#  {'id': [893512, 961680], 'id_layer': ['CAR', 'CAR']},
#  {'id': [893512, 961680], 'id_layer': ['CAR', 'CAR']},
#  {'id': [893512], 'id_layer': ['CAR']},
#  {'id': [893512], 'id_layer': ['CAR']},
#  {'id': [893512], 'id_layer': ['CAR']},
#  {'id': [893512], 'id_layer': ['CAR']},
#  {'id': [893512], 'id_layer': ['CAR']},
#  {'id': [893512], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [924781], 'id_layer': ['CAR']},
#  {'id': [924781], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [788479], 'id_layer': ['CAR']},
#  {'id': [788479], 'id_layer': ['CAR']},
#  {'id': [788479, 969508], 'id_layer': ['CAR', 'CAR']},
#  {'id': [788479, 969508], 'id_layer': ['CAR', 'CAR']},
#  {'id': [788479, 969508], 'id_layer': ['CAR', 'CAR']},
#  {'id': [788479, 969508], 'id_layer': ['CAR', 'CAR']},
#  {'id': [788479], 'id_layer': ['CAR']},
#  {'id': [788479], 'id_layer': ['CAR']},
#  {'id': [788479], 'id_layer': ['CAR']},
#  {'id': [788479], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [717971], 'id_layer': ['CAR']},
#  {'id': [717971], 'id_layer': ['CAR']},
#  {'id': [717971], 'id_layer': ['CAR']},
#  {'id': [717971], 'id_layer': ['CAR']},
#  {'id': [945446, 717971], 'id_layer': ['CAR', 'CAR']},
#  {'id': [945446, 717971], 'id_layer': ['CAR', 'CAR']},
#  {'id': [717971], 'id_layer': ['CAR']},
#  {'id': [717971], 'id_layer': ['CAR']},
#  {'id': [717971], 'id_layer': ['CAR']},
#  {'id': [717971], 'id_layer': ['CAR']},
#  {'id': [717971], 'id_layer': ['CAR']},
#  {'id': [717971], 'id_layer': ['CAR']},
#  {'id': [717971], 'id_layer': ['CAR']},
#  {'id': [717971], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [834796], 'id_layer': ['CAR']},
#  {'id': [834796], 'id_layer': ['CAR']},
#  {'id': [834796], 'id_layer': ['CAR']},
#  {'id': [834796], 'id_layer': ['CAR']},
#  {'id': [834796, 909050], 'id_layer': ['CAR', 'CAR']},
#  {'id': [834796, 909050], 'id_layer': ['CAR', 'CAR']},
#  {'id': [909050], 'id_layer': ['CAR']},
#  {'id': [909050], 'id_layer': ['CAR']},
#  {'id': [909050], 'id_layer': ['CAR']},
#  {'id': [909050], 'id_layer': ['CAR']},
#  {'id': [909050], 'id_layer': ['CAR']},
#  {'id': [909050], 'id_layer': ['CAR']},
#  {'id': [909050, 910259], 'id_layer': ['CAR', 'CAR']},
#  {'id': [909050, 910259], 'id_layer': ['CAR', 'CAR']},
#  {'id': [910259], 'id_layer': ['CAR']},
#  {'id': [910259], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [834777], 'id_layer': ['CAR']},
#  {'id': [834777], 'id_layer': ['CAR']},
#  {'id': [834777], 'id_layer': ['CAR']},
#  {'id': [834777], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [942834], 'id_layer': ['CAR']},
#  {'id': [942834], 'id_layer': ['CAR']},
#  {'id': [847221, 942834], 'id_layer': ['CAR', 'CAR']},
#  {'id': [847221, 942834], 'id_layer': ['CAR', 'CAR']},
#  {'id': [942834], 'id_layer': ['CAR']},
#  {'id': [942834], 'id_layer': ['CAR']},
#  {'id': [847068], 'id_layer': ['CAR']},
#  {'id': [847068], 'id_layer': ['CAR']},
#  {'id': [847068], 'id_layer': ['CAR']},
#  {'id': [847068], 'id_layer': ['CAR']},
#  {'id': [847068, 963468], 'id_layer': ['CAR', 'CAR']},
#  {'id': [847068, 963468], 'id_layer': ['CAR', 'CAR']},
#  {'id': [847068, 963468], 'id_layer': ['CAR', 'CAR']},
#  {'id': [847068, 963468], 'id_layer': ['CAR', 'CAR']},
#  {'id': [847068, 963468], 'id_layer': ['CAR', 'CAR']},
#  {'id': [847068, 963468], 'id_layer': ['CAR', 'CAR']},
#  {'id': [847068], 'id_layer': ['CAR']},
#  {'id': [847068], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [779634], 'id_layer': ['CAR']},
#  {'id': [779634], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [936766], 'id_layer': ['CAR']},
#  {'id': [936766], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [849493], 'id_layer': ['CAR']},
#  {'id': [849493], 'id_layer': ['CAR']},
#  {'id': [849493], 'id_layer': ['CAR']},
#  {'id': [849493], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [873090], 'id_layer': ['CAR']},
#  {'id': [873090], 'id_layer': ['CAR']},
#  {'id': [873090], 'id_layer': ['CAR']},
#  {'id': [873090], 'id_layer': ['CAR']},
#  {'id': [873090], 'id_layer': ['CAR']},
#  {'id': [873090], 'id_layer': ['CAR']},
#  {'id': [873090], 'id_layer': ['CAR']},
#  {'id': [873090], 'id_layer': ['CAR']},
#  {'id': [873090], 'id_layer': ['CAR']},
#  {'id': [873090], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [856138], 'id_layer': ['CAR']},
#  {'id': [856138], 'id_layer': ['CAR']},
#  {'id': [856138], 'id_layer': ['CAR']},
#  {'id': [856138], 'id_layer': ['CAR']},
#  {'id': [856138], 'id_layer': ['CAR']},
#  {'id': [856138], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [838721], 'id_layer': ['CAR']},
#  {'id': [756214, 838721], 'id_layer': ['CAR', 'CAR']},
#  {'id': [838721], 'id_layer': ['CAR']},
#  {'id': [756214, 838721], 'id_layer': ['CAR', 'CAR']},
#  {'id': [838721], 'id_layer': ['CAR']},
#  {'id': [756214, 838721], 'id_layer': ['CAR', 'CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [838729], 'id_layer': ['CAR']},
#  {'id': [756214, 838729], 'id_layer': ['CAR', 'CAR']},
#  {'id': [838729], 'id_layer': ['CAR']},
#  {'id': [756214, 838729], 'id_layer': ['CAR', 'CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [847070], 'id_layer': ['CAR']},
#  {'id': [756214, 847070], 'id_layer': ['CAR', 'CAR']},
#  {'id': [847070, 676163], 'id_layer': ['CAR', 'CAR']},
#  {'id': [756214, 847070, 676163], 'id_layer': ['CAR', 'CAR', 'CAR']},
#  {'id': [847070, 676163], 'id_layer': ['CAR', 'CAR']},
#  {'id': [756214, 847070, 676163], 'id_layer': ['CAR', 'CAR', 'CAR']},
#  {'id': [847070, 676163], 'id_layer': ['CAR', 'CAR']},
#  {'id': [756214, 847070, 676163], 'id_layer': ['CAR', 'CAR', 'CAR']},
#  {'id': [847070, 676163], 'id_layer': ['CAR', 'CAR']},
#  {'id': [756214, 847070, 676163], 'id_layer': ['CAR', 'CAR', 'CAR']},
#  {'id': [847070, 676163], 'id_layer': ['CAR', 'CAR']},
#  {'id': [756214, 847070, 676163], 'id_layer': ['CAR', 'CAR', 'CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [756214, 676163], 'id_layer': ['CAR', 'CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [756214, 676163], 'id_layer': ['CAR', 'CAR']},
#  {'id': [676163], 'id_layer': ['CAR']},
#  {'id': [756214, 676163], 'id_layer': ['CAR', 'CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [756214], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [790105], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [856138], 'id_layer': ['CAR']},
#  {'id': [856138], 'id_layer': ['CAR']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [22], 'id_layer': ['void']},
#  {'id': [873090], 'id_layer': ['CAR']},
#  {'id': [873090], 'id_layer': ['CAR']},
#  {'id': [873090], 'id_layer': ['CAR']},
#  ...]

# %%
gdf_broken_glass.drop(columns='representative_point', inplace=True)

# %%
# Converter a coluna 'id' em ambos os DataFrames para string
df_correlation_data = pd.DataFrame(data=correlation_data)
df_correlation_data["id"] = df_correlation_data["id"].astype(str)
gdf_broken_glass["id"] = gdf_broken_glass["id"].astype(str)

# Realizar o merge agora que as colunas estão no mesmo tipo
gdf_merged = gdf_broken_glass.merge(df_correlation_data, on="id", how="left")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 8
#       6 # Realizar o merge agora que as colunas estão no mesmo tipo
#       7 gdf_merged = gdf_broken_glass.merge(df_correlation_data, on="id", how="left")
# ----> 8 gdf_merged = gdf_merged[['id', 'overlapping_ids', 'geometry']]
#      10 # Exportar para GeoJSON
#      11 gdf_merged.to_file('split.geojson', driver="GeoJSON")
#
# File ~/Documents/GIT_WORKSPACE/split_offdb/_split_offdb/lib/python3.10/site-packages/geopandas/geodataframe.py:1750, in GeoDataFrame.__getitem__(self, key)
#    1744 def __getitem__(self, key):
#    1745     """
#    1746     If the result is a column containing only 'geometry', return a
#    1747     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1748     return a GeoDataFrame.
#    1749     """
# -> 1750     result = super().__getitem__(key)
#    1751     # Custom logic to avoid waiting for pandas GH51895
#    1752     # result is not geometry dtype for multi-indexes
#    1753     if (
#    1754         pd.api.types.is_scalar(key)
#    1755         and key == ""
#    (...)
#    1758         and not is_geometry_type(result)
#    1759     ):
#
# File ~/Documents/GIT_WORKSPACE/split_offdb/_split_offdb/lib/python3.10/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Documents/GIT_WORKSPACE/split_offdb/_split_offdb/lib/python3.10/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/Documents/GIT_WORKSPACE/split_offdb/_split_offdb/lib/python3.10/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['overlapping_ids'] not in index"

# %%
self.gdf_broken_glass["representative_point"] = self.gdf_broken_glass.geometry.apply(lambda x: x.representative_point())

correlation_data = []

for index, shard in self.gdf_broken_glass.iterrows():
    glass_shard_point = shard["representative_point"]
    overlapping_polygons = self.input_gdf[self.input_gdf.contains(glass_shard_point)]
    
    # Obtém o grid_id do objeto unidade_split
    grid_id = getattr(self.unidade_split, "grid_id", None)
    
    if not overlapping_polygons.empty:
        # Cria listas de 'id_layer' e 'id' e adiciona o grid_id como primeiro item
        id_layers = [grid_id] + overlapping_polygons["id_layer"].tolist()
        id_features = [grid_id] + overlapping_polygons["id"].tolist()
    else:
        # Para o caso vazio, adiciona o grid_id como primeiro item com valores padrão
        id_layers = [grid_id, "void"]
        id_features = [grid_id, getattr(self.unidade_split, "id", None)]
    
    # Armazena os resultados em correlation_data

# %%
gdf_merged = gdf_merged[['id', 'overlapping_ids', 'geometry']]

# Exportar para GeoJSON
gdf_merged.to_file('split.geojson', driver="GeoJSON")

# Visualizar o resultado
gdf_merged
