# %%
import geopandas as gpd
import shapely
import pandas as pd

# %%
eua=gpd.read_file('/home/pedro/Documents/DADOS/ibge/BR_UF_2024/BR_UF_2024.shp')

# %%
desc = []

for index, row in eua.iterrows():
    desc.append(row[["gid", "geom"]].to_dict())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 4
#       1 desc = []
#       3 for index, row in eua.iterrows():
# ----> 4     desc.append(row[["gid", "geom"]].to_dict())
#
# File ~/Documents/GIT_WORKSPACE/split_offdb/_split_offdb/lib/python3.10/site-packages/pandas/core/series.py:1153, in Series.__getitem__(self, key)
#    1150     key = np.asarray(key, dtype=bool)
#    1151     return self._get_rows_with_mask(key)
# -> 1153 return self._get_with(key)
#
# File ~/Documents/GIT_WORKSPACE/split_offdb/_split_offdb/lib/python3.10/site-packages/pandas/core/series.py:1194, in Series._get_with(self, key)
#    1191         return self.iloc[key]
#    1193 # handle the dup indexing case GH#4246
# -> 1194 return self.loc[key]
#
# ...

# %%
gdf = gpd.GeoDataFrame(data = pd.DataFrame(desc), geometry='geometry', crs = 'EPSG:4674')
gdf.to_file('feicoes_descartadas.shp')
