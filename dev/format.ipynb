# %%
import geopandas as gpd
import numpy as np
import ast

# %%
gdf = gpd.read_file('/home/pedro/Documents/GIT_WORKSPACE/split_offdb/teste.shp')
gdf
# Out:
#         id                              id_layer  \
# 0        1                       ['GRID', 'MUN']
# 1        2                       ['GRID', 'MUN']
# 2        3                ['GRID', 'MUN', 'CAR']
# 3        4                ['GRID', 'MUN', 'CAR']
# 4        5         ['GRID', 'CAR', 'CAR', 'MUN']
# ...    ...                                   ...
# 1421  1422         ['GRID', 'CAR', 'CAR', 'MUN']
# 1422  1423  ['GRID', 'CAR', 'MUN', 'CAR', 'CAR']
# 1423  1424  ['GRID', 'MUN', 'CAR', 'CAR', 'CAR']
# 1424  1425         ['GRID', 'MUN', 'CAR', 'CAR']
# 1425  1426                ['GRID', 'CAR', 'MUN']
#
#                                     id_feature  \
# 0                                [99, 1400209]
# 1                                [99, 1400282]
# 2                       [99, 1400282, 5959423]
# 3                       [99, 1400308, 5959423]
# 4             [99, 13168762, 5959423, 1400282]
# ...                                        ...
# ...

# %%
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       3
#        ..
# 1421    3
# 1422    2
# 1423    1
# 1424    1
# 1425    2
# Name: id_layer, Length: 1426, dtype: int64

# %%
#Inserir coluna cd_uf
gdf['cd_uf'] = gdf['cd_mun'].astype(str).str[:2].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 #Inserir coluna cd_uf
# ----> 2 gdf['cd_uf'] = gdf['cd_mun'].astype(str).str[:2].astype(int)
#
# File ~/Documents/GIT_WORKSPACE/split_offdb/_split_offdb/lib/python3.10/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %%
#Contagem de CARs
gdf['n_car'] = np.array([x.count('CAR') for x in gdf['id_layer']])
